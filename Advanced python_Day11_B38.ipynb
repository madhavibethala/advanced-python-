# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('countries.csv')
df
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
us=df[df.country=='United States']
us
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
df.country=='United States'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: country, Length: 1704, dtype: bool

# %%
china=df[df.country=='China']
china
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
plt.plot(us.year,us.population)
plt.plot(china.year,china.population)
plt.xlabel('year')
plt.ylabel('population')
plt.legend(['us','china'])
plt.show()

# %%
countries_list=pd.read_csv('countries.csv')

countries_list['country'].unique().tolist()
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Bahrain',
#  'Bangladesh',
#  'Belgium',
#  'Benin',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'Gabon',
#  'Gambia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Haiti',
#  'Honduras',
#  'Hong Kong, China',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
# ...

# %%
# Activity: 5 countries plot
brazil=df[df.country=='Brazil']
india=df[df.country=='India']
somalia=df[df.country=='Somalia']
plt.plot(us.year,us.population)
plt.plot(china.year,china.population)
plt.plot(brazil.year,brazil.population)
plt.plot(india.year,india.population)
plt.plot(somalia.year,somalia.population)
#plt.
plt.xlabel('year')
plt.ylabel('population')
plt.legend(['us','china','brazil','india','somalia'])
plt.show()

# %%
#Bar graphs
# creating academy students enrollment


data={'c':20,'c++':15,'java':5,'python':35}
courses=list(data.keys())
values=list(data.values())
#fig=plt.figure('figsize=(10,5)')
plt.bar(courses,values,color='red',width=0.4)
plt.xlabel('courses')
plt.ylabel('students')
plt.title('students enrollment')
plt.show()

# %%
# intro to pie chart

cars=['audi','bmw','maruti','benz','tesla','jaguor']
data=[23,17,35,29,12,25]
fig=plt.figure(figsize=(10,7))
plt.pie(data,labels=cars)
plt.show()
